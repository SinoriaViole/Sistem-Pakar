# %%
import os

print("+===============================================+")
print("|\tSelamat Datang di Aplikasi Sistem Pakar \t|")
print("|\tDeteksi Awal penyakit jantung           \t|")
print("+===============================================+")
nama = input("Nama\t: ")
pilihan = input("Hallo " + nama + ", \nApakah anda ingin melakukan Diagnosa? (Iya/Tidak)")

os.system("cls")

while pilihan == "Iya":
    print("\nApakah anda mengalami beberapa gejala seperti dibawah ini : ")
    print("1.  Nyeri dada ")
    print("2.  Bahu kiri terasa tidak enak")
    print("3.  Keringat dingin")
    print("4.  Sesak nafas")
    print("5.  Gangguan Pencernaan")
    print("6.  Mual")
    print("7.  Detak Jantung tidak teratur")
    print("8.  Pusing")
    print("9.  Kaki bengkak")
    print("10. Jantung berdebar-debar")
    print("11. Mudah lelah")
    print("12. Nyeri didaerah dada tengah")
    print("13. Mudah berkeringat")
    print("14. Dada mengencang")
    print("15. Pembengkakan pada jantung")
    print("16. Kelainan fungsi hati")
    print("17. Pendarahan dari hidung")
    print("18. Wajah kemerahan")
    print("19. Batuk")
    print("20. Sakit Perut")
    print("21. Detak jantung cepat")
    print("22. Nyeri didaerah lengan kiri")
    print("23. Punggung terasa tidak enak")
    print("24. Sakit Kepala")
    diagnosa1 = input("Jawab (Iya/Tidak) :")

    if diagnosa1 == "Tidak":
        print("+=====================Terimakasih=====================+")
        break
    elif diagnosa1 == "Iya":
        print("\nApakah anda juga merasakan gejala seperti ini ? ")
        print("1. Nyeri dada")
        print("2. Bahu kiri terasa tidak enak")
        print("3. Keringat dingin")
        print("4. Sesak nafas")
        print("5. Gangguan pencernaan")
        print("6. Mual")
        print("7. Detak jantung tidak teratur")
        print("8. Lengan kiri terasa tidak enak")
        print("9. Punggung terasa tidak enak")
        diagnosaR01 = input("Jawab (Iya/Tidak):")

    if diagnosaR01 == "Iya":
        print("\nHallo " + nama + ", Hasil diagnosa kamu adalah : ")
        print("Kamu terkena Penyakit Jantung koroner, Segeralah pergi ke dokter")

    elif diagnosaR01 == "Tidak":
        print("\nApakah anda juga merasakan gejala ini? :")
        print("1. Sesak nafas")
        print("2. Pusing")
        print("3. Kaki bengkak")
        print("4. Jantung berdebar-debar")
        print("5. Mudah lelah")
        print("6. Detak jantung tidak teratur")
        diagnosaR02 = input("Jawab (Iya/Tidak/Selesai):")

        if diagnosaR02 == "Iya":
            print("\nHallo " + nama + ", Hasil diagnosa kamu adalah : ")
            print("\nKamu terkena Penyakit Otot jantung (Kardiomiopati) segeralah ke dokter : ")

        elif diagnosaR02 == "Tidak":
            print("\nApakah anda juga mengalami gejala ini? :")
            print("1. Nyeri didaerah dada tengah ")
            print("2. Mudah berkeringat")
            print("3. Dada mengencang")
            print("4. Nyeri didaerah lengan kiri ")
            print("5. Penebalan tondon achiles")
            diagnosaR03 = input("Jawab(Iya/Tidak):")

        if diagnosaR03 == "Iya":
            print("\nHallo " + nama + ", Hasil diagnosa kamu adalah : ")
            print("\nKamu terkena Penyakit Jantung Iskemik segeralah ke dokter : ")

        elif diagnosaR03 == "Tidak":
            print("\nApakah anda juga mengalami gejala ini? :")
            print("1. Sesak Nafas ")
            print("2. Pembengkakan pada Jantung")
            print("3. Kelainan fungsi Jantung")
            diagnosaR04 = input("Jawab(Iya/Tidak):")

        if diagnosaR04 == "Iya":
            print("\nHallo " + nama + ", Hasil diagnosa kamu adalah : ")
            print("\nKamu terkena Penyakit Gagal Jantung segeralah ke dokter : ")

        elif diagnosaR04 == "Tidak":
            print("\nApakah anda juga mengalami gejala ini? :")
            print("1. Sakit Kepala ")
            print("2. Pendarahan dari Hidung")
            print("3. Pusing")
            print("4. Wajah kemerahan ")
            print("5. Mudah lelah")
            diagnosaR05 = input("Jawab(Iya/Tidak):")

        if diagnosaR05 == "Iya":
            print("\nHallo " + nama + ", Hasil diagnosa kamu adalah : ")
            print("\nKamu terkena Penyakit jantung Hipertensi segeralah ke dokter : ")

        elif diagnosaR05 == "Tidak":
            print("\nApakah anda juga mengalami gejala ini? :")
            print("1. Mudah lelah ")
            print("2. Jantung berdebar-debar")
            print("3. Nyeri dada")
            print("4. sesak nafas ")
            print("5. batuk")
            print("6. Kaki bengkak ")
            diagnosaR06 = input("Jawab(Iya/Tidak):")

        if diagnosaR06 == "Iya":
            print("\nHallo " + nama + ", Hasil diagnosa kamu adalah : ")
            print("\nKamu terkena Penyakit Katup jantung segeralah ke dokter : ")

        elif diagnosaR06 == "Tidak":
            print("\nApakah anda juga mengalami gejala ini? :")
            print("1. Sakit perut ")
            print("2. Detak jantung tak teratur")
            print("3. Detak jantung cepat")
            print("4. Nyeri dada ")
            diagnosaR07 = input("Jawab(Iya/Tidak):")

        if diagnosaR07 == "Iya":
            print("\nHallo " + nama + ", Hasil diagnosa kamu adalah : ")
            print("\nKamu terkena Penyakit jantung Hipertrofik(kardiomegali) segeralah ke dokter : ")
        elif diagnosaR07 == "Tidak":
            print("\nSilahkan melakukan pemeriksaan langsung ke rumah sakit :")
        else:
            print("\nSilahkan melakukan pemeriksaan langsung ke rumah sakit :")

    elif diagnosa1 == "Tidak":
        print("+===========================================+")
        pilihan = input("Hallo " + nama + ", \nApakah anda ingin melakukan diagnosa? (Iya/Tidak)")

    if pilihan == "Iya":
        os.system("cls")
        print("+====================================================+")
        print("|\tSelamat datang di Aplikasi Sistem Pakar \t|")
        print("|\tDeteksi Awal penyakit jantung           \t|")
        print("+====================================================+")
    else:
        print("+=====================Terimakasih=====================+")
# Out:
# +===============================================+
# |	Selamat Datang di Aplikasi Sistem Pakar 	|
# |	Deteksi Awal penyakit jantung           	|
# +===============================================+
# Nama	: Deni
# Hallo Deni,
# Apakah anda ingin melakukan Diagnosa? (Iya/Tidak)Iya
#
# Apakah anda mengalami beberapa gejala seperti dibawah ini :
# 1.  Nyeri dada
# 2.  Bahu kiri terasa tidak enak
# 3.  Keringat dingin
# 4.  Sesak nafas
# 5.  Gangguan Pencernaan
# 6.  Mual
# 7.  Detak Jantung tidak teratur
# 8.  Pusing
# 9.  Kaki bengkak
# 10. Jantung berdebar-debar
# 11. Mudah lelah
# 12. Nyeri didaerah dada tengah
# 13. Mudah berkeringat
# 14. Dada mengencang
# 15. Pembengkakan pada jantung
# 16. Kelainan fungsi hati
# 17. Pendarahan dari hidung
# 18. Wajah kemerahan
# 19. Batuk
# 20. Sakit Perut
# 21. Detak jantung cepat
# 22. Nyeri didaerah lengan kiri
# 23. Punggung terasa tidak enak
# 24. Sakit Kepala
# Jawab (Iya/Tidak) :Iya
#
# Apakah anda juga merasakan gejala seperti ini ?
# ...
